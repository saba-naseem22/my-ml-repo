# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saba-naseem22/my-ml-repo/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# choosen lane: SEO performance and content optimization
# Why:this lane will help me to identify search related queries and the pages not performing well.Aafter looking the real data, we can apply the strategy to improve traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Analysis: page /query level search matrics
# improved decision: decide which pages needs updates or re-optimization.
# Actions: writing titles again,text updations,or fixing search for underperforming pages.
# cost of wrong cell:Creating the wrong pages and missing the pages that can bring more visitors from Google.
# why data/ML helps: Data and machine learning show what needs improvement, so you don't have to guess.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/saba-naseem22/my-ml-repo/main/data/raw/content_refresh_anonymized.csv")
print("total rows:",len(df))
print("total clicks:",df["clicks_90d"].sum())
print("total impressions:",df["impressions_90d"].sum())
# Out:
# total rows: 30000
# total clicks: 482920
# total impressions: 156010989

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#  CAN Claim
# I can find patterns and connections between content, impressions, rankings, and website traffic using this dataset.
# CANNOT Claim
# I cannot say that one change will definitely improve Google rankings or predict future Google algorithm updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
